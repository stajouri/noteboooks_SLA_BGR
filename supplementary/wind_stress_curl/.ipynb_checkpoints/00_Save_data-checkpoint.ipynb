# %%
## standart libraries
import os,sys
import numpy as np
# xarray
import xarray as xr
# plot
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import matplotlib.pyplot as plt
from matplotlib.colors import Colormap
import matplotlib.colors as mcolors
import matplotlib.dates as mdates
import matplotlib.cm as cm
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.colors import from_levels_and_colors
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
import multiprocessing.popen_spawn_posix
from dask.distributed import Client
c = Client()
c
# Out:
# /linkhome/rech/genlop01/uor98hu/.local/lib/python3.9/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41257 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:39855' processes=5 threads=10, memory=20.00 GiB>

# %% [markdown]
# # Loading data

# %%
# from the scratch
path = '/gpfsscratch/rech/cli/uor98hu/Calcul_curl/'

chunk_size = {"x":500,"y":500}
dataGAI = xr.open_mfdataset(path+'eORCA025.L75-IMHOTEP.GAI_y*_1y_curl.nc', chunks=chunk_size, parallel=True).squeeze()
dataAI  = xr.open_mfdataset(path+'eORCA025.L75-IMHOTEP.AI_y*_1y_curl.nc', chunks=chunk_size, parallel=True).squeeze()
dataS   = xr.open_mfdataset(path+'eORCA025.L75-IMHOTEP.S_y*_1y_curl.nc', chunks=chunk_size, parallel=True).squeeze()

# save it in my work (just once)
dataGAI.to_netcdf('/gpfswork/rech/cli/uor98hu/MYDATA/wind_curl/eORCA025.L75-IMHOTEP.GAI_y1980-2018_1y_curl.nc', mode='w')
dataAI.to_netcdf('/gpfswork/rech/cli/uor98hu/MYDATA/wind_curl/eORCA025.L75-IMHOTEP.AI_y1980-2018_1y_curl.nc', mode='w')
dataS.to_netcdf('/gpfswork/rech/cli/uor98hu/MYDATA/wind_curl/eORCA025.L75-IMHOTEP.S_y1980-2018_1y_curl.nc', mode='w')
